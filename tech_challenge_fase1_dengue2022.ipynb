# %% [markdown]
# #### Tech Challenge - Fase 1: Análise de Dados de Dengue 2022
#
# #### 🦟 Projeto Tech Challenge IA para Devs - Sistema de Diagnóstico de Dengue com Machine Learning
#
# #### 📋 Visão Geral do Projeto
#
# **Objetivo Principal:** Desenvolver um modelo de Machine Learning capaz de auxiliar na triagem e diagnóstico de casos suspeitos de dengue, classificando-os como **Confirmado** ou **Descartado** com base em dados clínicos e epidemiológicos.
#
# **Contexto:** Um hospital universitário brasileiro precisa acelerar a triagem de pacientes com suspeita de dengue durante períodos de surto, quando o volume de casos aumenta exponencialmente.

# %% [markdown]
# ## 1. Importação de Bibliotecas

# %%
# Manipulação e análise de dados
import pandas as pd

# %% [markdown]
# ## 2. Carregamento dos Dados
#
# Nesta seção, carregue o dataset de dengue 2022. Ajuste o caminho do arquivo conforme necessário.

# %%
# Carregar dados de dengue 2022
df = pd.read_csv('DENGBR22.csv')

print(f"✓ Dataset carregado com sucesso!")
print(f"Dimensões: {df.shape[0]} linhas e {df.shape[1]} colunas")
# Out:
# C:\Users\legio\AppData\Local\Temp\ipykernel_41924\2717437312.py:2: DtypeWarning: Columns (22,44,45,46,54,101) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('DENGBR22.csv')
# ✓ Dataset carregado com sucesso!
# Dimensões: 1393877 linhas e 121 colunas

# %% [markdown]
# ### 2.1 Visualização Inicial dos Dados

# %%
# Visualizar primeiras linhas
df.head(10)
# Out:
#    TP_NOT ID_AGRAVO  DT_NOTIFIC  SEM_NOT  NU_ANO  SG_UF_NOT  ID_MUNICIP  \
# 0       2       A90  2022-01-12   202202    2022         12      120020
# 1       2       A90  2022-08-11   202232    2022         12      120020
# 2       2       A90  2022-03-25   202212    2022         12      120020
# 3       2       A90  2022-03-07   202210    2022         12      120020
# 4       2       A90  2022-01-18   202203    2022         12      120020
# 5       2       A90  2022-02-21   202208    2022         12      120020
# 6       2       A90  2022-01-21   202203    2022         12      120020
# 7       2       A90  2022-02-15   202207    2022         12      120020
# 8       2       A90  2022-10-28   202243    2022         12      120020
# 9       2       A90  2022-02-17   202207    2022         12      120020
#
#    ID_REGIONA  ID_UNIDADE  DT_SIN_PRI  ...  EVIDENCIA  PLAQ_MENOR  CON_FHD  \
# 0      1941.0   6801099.0  2022-01-06  ...        NaN         NaN      NaN
# ...

# %%
# Informações sobre as colunas e tipos de dados
print("=== INFORMAÇÕES DO DATASET ===\n")
df.info()
print("\n" + "="*50)
print(f"\nNomes das colunas:\n{df.columns.tolist()}")
# Out:
# === INFORMAÇÕES DO DATASET ===
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1393877 entries, 0 to 1393876
# Columns: 121 entries, TP_NOT to MIGRADO_W
# dtypes: float64(94), int64(8), object(19)
# memory usage: 1.3+ GB
#
# ...
#
# Nomes das colunas:
# ...

# %%
# Estatísticas descritivas das variáveis
df.describe(include='all').T
# Out:
#                 count unique         top     freq          mean       std  \
# TP_NOT      1393877.0    NaN         NaN      NaN      2.000006  0.002396
# ID_AGRAVO     1393877      1         A90  1393877           NaN       NaN
# DT_NOTIFIC    1393877    364  2022-04-25    22831           NaN       NaN
# SEM_NOT     1393877.0    NaN         NaN      NaN  202218.85215   9.42448
# NU_ANO      1393877.0    NaN         NaN      NaN        2022.0       0.0
# ...               ...    ...         ...      ...           ...       ...
# NDUPLIC_N      1439.0    NaN         NaN      NaN           1.0       0.0
# DT_DIGITA     1375836    530  2022-04-26    20065           NaN       NaN
# CS_FLXRET         0.0    NaN         NaN      NaN           NaN       NaN
# FLXRECEBI         0.0    NaN         NaN      NaN           NaN       NaN
# MIGRADO_W         0.0    NaN         NaN      NaN           NaN       NaN
#
#                  min       25%       50%       75%       max
# ...
